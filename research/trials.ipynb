# %%
d = {"key1":"value1","key2":"value2"}

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Rmkmr\OneDrive\Desktop\Streamlit\Data-Science-with-mlflow\research\trials.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rmkmr/OneDrive/Desktop/Streamlit/Data-Science-with-mlflow/research/trials.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key1":"2","key2":"3"})

# %%
d2.key1
# Out:
# '2'
